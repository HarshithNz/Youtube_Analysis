# %% [markdown]
# ***Exploratory Data Analysis on YouTube Data***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.**

# %%
df=pd.read_csv("/content/drive/MyDrive/DataAnalysis/youtube_dislike_dataset.csv")

# %%
df.head(5)
#Printing top 5 rows.
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail(5)
#Printing bottom 5 Rows.
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# **2.Check the info of the dataframe and write your inferences on data types and shape of the dataset.**

# %%
df.info()
#checking the info of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
#checking the shape of the dataframe
# Out:
# (37422, 12)

# %% [markdown]
# **Inference:**
# The Following dataframe consists of 37422 rows and 12 columns. Each row represents the data about a video published on youtube. The dataframe hosts 12 variables and is having Null Values only in the comments column. The whole dataframe is of Object datatype and on individual level the dataframe hosts 8 columns of object datatypes and 4 of Int64 datatypes.

# %% [markdown]
# **3.Check for the Percentage of the missing values and drop or impute them.**

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
percent=(158/37422)*100
percent
#Analyzing the percentages of missing values
# Out:
# 0.4222115333226444

# %%
df.drop("comments",axis=1,inplace=True)
#Dropping Comments column.

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# dtype: int64

# %% [markdown]
# **4.Check the statistical summary of both numerical and categorical columns and write your inferences.**

# %%
df.describe()
#getting the Statistical Summary of the Numerical columns.
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df[['video_id','title','channel_id','channel_title','description','tags','published_at']].describe()
#getting the Statistical Summary of the Categorical columns.
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#        description   tags         published_at
# count        37422  37422                37422
# unique       35630  28799                36772
# top                        2020-10-16 04:00:10
# freq           589   3817                    6

# %%
df.describe(include="all")
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %% [markdown]
# **Inference :**
# The Numerical Columns consists of view_counts,likes,dislikes,comment_count. The Statistical summary for the numerical datatypes provides us with the descriptive details about our dataset. We can get a good idea from viewing the mean of the numberical columns of the dataframe. and getting the quartiles helps us to undersatand the data points. Whereas the Categorical column provides us with a good understanding of the dataset as a whole.

# %% [markdown]
# **5.Convert datatype of column published_at from object to pandas datetime.**

# %%
df["published_at"]=pd.to_datetime(df["published_at"])
#Conversion of column published_at from object to pandas datetime.

# %%
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# dtype: object

# %% [markdown]
# **6.Create a new column as 'published_month' using the column published_at (display the months only)**

# %%
import datetime as dt

# %%
df['published_month']=df['published_at'].dt.month_name()

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# **7.Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'**
# **and so on.**

# %%
df['published_month'].replace({'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12},inplace=True)

# %%
df["published_month"]
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int64

# %% [markdown]
# **8.Find the number of videos published each month and arrange the months in a decreasing order based** **on the video count.**

# %%
a=df[["published_month","video_id"]].groupby("published_month")

# %%
a.count()
# Out:
#                  video_id
# published_month
# 1                    2108
# 2                    2137
# 3                    2258
# 4                    2126
# 5                    2081
# 6                    2316
# 7                    2340
# 8                    4262
# 9                    4880
# 10                   4991
# 11                   4851
# 12                   3072

# %%
a.count().sort_values(by='video_id',ascending=False)
# Out:
#                  video_id
# published_month
# 10                   4991
# 9                    4880
# 11                   4851
# 8                    4262
# 12                   3072
# 7                    2340
# 6                    2316
# 3                    2258
# 2                    2137
# 4                    2126
# 1                    2108
# 5                    2081

# %% [markdown]
# **9.Find the count of unique video_id, channel_id and channel_title.**

# %%
video=df['video_id'].unique()
video
# Out:
# array(['--0bCF-iK2E', '--14w5SOEUs', '--40TEbZ9Is', ..., 'zzk09ESX7e0',
#        'zzmQEb0Em5I', 'zzxPZwaA-8w'], dtype=object)

# %%
len(video)
# Out:
# 37422

# %%
channel=df['channel_id'].unique()
print(channel)
len(channel)
# Out:
# ['UC6UL29enLNe4mqwTfAyeNuw' 'UCGIelM2Dj3zza3xyV3pL3WQ'
#  'UClBKH8yZRcM4AsRjDVEdjMg' ... 'UC95x-m2toVa_BRmmQ6SrIYg'
#  'UCb5jIJ27Ds32YE6xX3eIO3g' 'UC8NjnNWMsRqq11NYvHAQb1g']
# 10961

# %%
len(df['channel_title'].unique())
# Out:
# 10883

# %% [markdown]
# **10.Find the top10 channel names having the highest number of videos in the dataset and the bottom 10 having lowest number of videos.**

# %%
data=df[["channel_title","video_id"]].groupby("channel_title")

# %%
data.count()
# Out:
#                       video_id
# channel_title
#    SilverName                1
#    [KIMDUMB]                 1
#   (Inter TV channel)         1
#   -    IT!                   1
#   - MBN                      1
# ...                        ...
# zanny                        5
# zayn                         1
# zefrank1                     9
# zollotech                   10
# zoom                         1
#
# [10883 rows x 1 columns]

# %%
data.count().sort_values(by="video_id",ascending=False)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# ...                       ...
# Kannada Cinema              1
# KanalD                      1
# Kanak News                  1
# Kamille Ramos               1
# zoom                        1
#
# [10883 rows x 1 columns]

# %%
data.count().sort_values(by='video_id',ascending=False).head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
data.count().sort_values(by='video_id',ascending=False).tail(10)
# Out:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %% [markdown]
# **11.Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.**

# %%
b=df[['title','likes']].groupby('title')

# %%
b.max().sort_values(by="likes",ascending=False).head(1)
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
df[['title','likes']].groupby('title').max().sort_values(by="likes",ascending=False).tail(1)
# Out:
#                                                     likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0

# %% [markdown]
# **Inference :**
# The most liked video is the BTS () 'Dynamite' Official MV having 31837675 likes and the minimum is of Kim Kardashian's Must-See Moments on "Saturday Night Live" haing 0 likes. It is also observed that the videos having higher number of likes are having higher number of views too.

# %% [markdown]
# **12.Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.**

# %%
df[['title','dislikes']].groupby('title').max().sort_values(by="dislikes",ascending=False).head(1)
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
df[['title','dislikes']].groupby('title').max().sort_values(by="dislikes",ascending=False).tail(1)
# Out:
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0

# %% [markdown]
# **Inference :**
# The least dislikes video is: 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News and the most disliked video is 'Cuties | Official Trailer | Netflix'.

# %% [markdown]
# **13.Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.**

# %%
plt.scatter(df["view_count"], df["dislikes"])
plt.xlabel("Views")
plt.ylabel("Dislikes")
plt.title("Correlation between Views and Dislikes")
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-111-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
corr = df["view_count"].corr(df["dislikes"])
corr
# Out:
# 0.6844687753905545

# %% [markdown]
# **Inference :**
# The correlation between views and dislikes is 0.684. It means it's having a direct relation and increase in one leads to increase in another and vice-versa

# %% [markdown]
# **14.Display all the information about the videos that were published in January, and mention the count of videos that were published in January.**

# %%
df[df["published_month"]==1]
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
df[df["published_month"]==1].describe()
# Out:
#          view_count         likes       dislikes  comment_count  \
# count  2.108000e+03  2.108000e+03    2108.000000   2.108000e+03
# mean   4.976449e+06  1.315030e+05    3614.568311   8.923385e+03
# std    2.055331e+07  3.886887e+05   13946.711333   3.664662e+04
# min    2.845000e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.322335e+05  1.032400e+04     249.000000   8.747500e+02
# 50%    1.147500e+06  3.173900e+04     729.000000   2.328500e+03
# 75%    3.227483e+06  1.076512e+05    2243.250000   6.302000e+03
# max    6.203274e+08  7.828036e+06  409144.000000   1.095119e+06
#
#        published_month
# count           2108.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %%
df[df["published_month"]==1].shape[0]
# Out:
# 2108

# %%
df[df["published_month"]==1]["video_id"].count()
# Out:
# 2108
